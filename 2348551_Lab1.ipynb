# %% [markdown]
# <a href="https://colab.research.google.com/github/szm7/AML/blob/main/2348551_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.io as pio
pio.templates.default = "plotly_white"

# %%
data = pd.read_csv("/content/Program_1_Dataset.csv")

# %%
data.head()
# Out:
#    Crime_Rate  Zone_proportion  Non_Retail_Acres  CHAS    NOX  Avg_rooms   \
# 0     0.06860              0.0              2.89     0  0.445       7.416
# 1     0.14866              0.0              8.56     0  0.520       6.727
# 2     0.11432              0.0              8.56     0  0.520       6.781
# 3     0.22876              0.0              8.56     0  0.520       6.405
# 4     0.21161              0.0              8.56     0  0.520       6.137
#
#     AGE  Distance  RAD  Property_TaxRate  PTRATIO       B  LSTAT  MValue
# 0  62.5    3.4952    2               276     18.0  396.90   6.19    33.2
# 1  79.9    2.7778    5               384     20.9  394.76   9.42    27.5
# 2  71.3    2.8561    5               384     20.9  395.58   7.67    26.5
# 3  85.4    2.7147    5               384     20.9   70.80  10.63    18.6
# 4  87.4    2.7147    5               384     20.9  394.47  13.44    19.3

# %%
data.isnull().sum()
# Out:
# Crime_Rate          0
# Zone_proportion     0
# Non_Retail_Acres    0
# CHAS                0
# NOX                 0
# Avg_rooms           0
# AGE                 0
# Distance            0
# RAD                 0
# Property_TaxRate    0
# PTRATIO             0
# B                   0
# LSTAT               0
# MValue              0
# dtype: int64

# %%
data['Avg_rooms '].head()
# Out:
# 0    7.416
# 1    6.727
# 2    6.781
# 3    6.405
# 4    6.137
# Name: Avg_rooms , dtype: float64

# %%
data['MValue'].head()
# Out:
# 0    33.2
# 1    27.5
# 2    26.5
# 3    18.6
# 4    19.3
# Name: MValue, dtype: float64

# %%
mean = data['MValue'].mean()
mean
# Out:
# 22.532806324110673

# %%
fig = px.scatter(x=data['Avg_rooms '], y=data['MValue'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
z_scores = np.abs((data - data.mean()) / data.std())
threshold = 3
df_clean = data[(z_scores < threshold).all(axis=1)]
print(df_clean)
# Out:
#      Crime_Rate  Zone_proportion  Non_Retail_Acres  CHAS    NOX  Avg_rooms   \
# 0       0.06860              0.0              2.89     0  0.445       7.416
# 1       0.14866              0.0              8.56     0  0.520       6.727
# 2       0.11432              0.0              8.56     0  0.520       6.781
# 4       0.21161              0.0              8.56     0  0.520       6.137
# 5       0.13960              0.0              8.56     0  0.520       6.167
# ..          ...              ...               ...   ...    ...         ...
# 500     9.96654              0.0             18.10     0  0.740       6.485
# 501    12.80230              0.0             18.10     0  0.740       5.854
# 503     6.28807              0.0             18.10     0  0.740       6.341
# 504     9.92485              0.0             18.10     0  0.740       6.251
# 505     9.32909              0.0             18.10     0  0.713       6.185
#
# ...

# %%
fig = px.scatter(x=df_clean['Avg_rooms '], y=df_clean['MValue'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
x = df_clean[['Avg_rooms ']]
y = df_clean[['MValue']]

# %%
model1 = 10+3*df_clean['Avg_rooms ']
model2 = 9+3*df_clean['Avg_rooms ']
print(model1)
print(model2)
# Out:
# 0      32.248
# 1      30.181
# 2      30.343
# 4      28.411
# 5      28.501
#         ...
# 500    29.455
# 501    27.562
# 503    29.023
# 504    28.753
# 505    28.555
# Name: Avg_rooms , Length: 415, dtype: float64
# 0      31.248
# 1      29.181
# 2      29.343
# 4      27.411
# 5      27.501
#         ...
# 500    28.455
# 501    26.562
# 503    28.023
# 504    27.753
# 505    27.555
# Name: Avg_rooms , Length: 415, dtype: float64

# %%
df_clean['Model_1'] = model1
df_clean['Model_2'] = model2
df_clean['Model_3']=df_clean['MValue'].mean()
df_clean.head()
# Out:
# <ipython-input-98-d0995ac3d337>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-98-d0995ac3d337>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-98-d0995ac3d337>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
fig, ax =plt.subplots()
ax.scatter(x='Avg_rooms ' , y='MValue',data = data,label = 'Actual repair time')
ax.plot(df_clean['Avg_rooms '],df_clean['Model_1'],color='red',label = 'Model1')
ax.plot(df_clean['Avg_rooms '],df_clean['Model_2'],color='red',label = 'Model2')
ax.plot(df_clean['Avg_rooms '],df_clean['Model_3'],color='red',label = 'Model3')
ax.set_ylabel('MValue')
ax.set_xlabel('Avg_rooms ')
ax.set_title("Speculayed Models")
ax.legend()

# %%
model_1_obs=pd.DataFrame({
            'Avg_rooms':df_clean['Avg_rooms '],
            'Actual_MValue':df_clean['MValue'],
            'Predicted_MValue':df_clean['Model_1'],
            'Error':(df_clean['Model_1']-df_clean['MValue'])
})

model_1_obs
# Out:
#      Avg_rooms  Actual_MValue  Predicted_MValue   Error
# 0        7.416           33.2            32.248  -0.952
# 1        6.727           27.5            30.181   2.681
# 2        6.781           26.5            30.343   3.843
# 4        6.137           19.3            28.411   9.111
# 5        6.167           20.1            28.501   8.401
# ..         ...            ...               ...     ...
# 500      6.485           15.4            29.455  14.055
# 501      5.854           10.8            27.562  16.762
# 503      6.341           14.9            29.023  14.123
# 504      6.251           12.6            28.753  16.153
# 505      6.185           14.1            28.555  14.455
#
# [415 rows x 4 columns]

# %%
sum(model_1_obs['Error']**2)
# Out:
# 36655.06504900001

# %%
model_2_obs=pd.DataFrame({
            'Avg_rooms':df_clean['Avg_rooms '],
            'Actual_MValue':df_clean['MValue'],
            'Predicted_MValue':df_clean['Model_2'],
            'Error':(df_clean['Model_2']-df_clean['MValue'])
})

model_2_obs
# Out:
#      Avg_rooms  Actual_MValue  Predicted_MValue   Error
# 0        7.416           33.2            31.248  -1.952
# 1        6.727           27.5            29.181   1.681
# 2        6.781           26.5            29.343   2.843
# 4        6.137           19.3            27.411   8.111
# 5        6.167           20.1            27.501   7.401
# ..         ...            ...               ...     ...
# 500      6.485           15.4            28.455  13.055
# 501      5.854           10.8            26.562  15.762
# 503      6.341           14.9            28.023  13.123
# 504      6.251           12.6            27.753  15.153
# 505      6.185           14.1            27.555  13.455
#
# [415 rows x 4 columns]

# %%
sum(model_2_obs['Error']**2)
# Out:
# 31717.65504899998

# %%
model_3_obs=pd.DataFrame({
            'Avg_rooms':df_clean['Avg_rooms '],
            'Actual_MValue':df_clean['MValue'],
            'Predicted_MValue':df_clean['Model_3'],
            'Error':(df_clean['Model_3']-df_clean['MValue'])
})

model_3_obs
# Out:
#      Avg_rooms  Actual_MValue  Predicted_MValue      Error
# 0        7.416           33.2         22.353976 -10.846024
# 1        6.727           27.5         22.353976  -5.146024
# 2        6.781           26.5         22.353976  -4.146024
# 4        6.137           19.3         22.353976   3.053976
# 5        6.167           20.1         22.353976   2.253976
# ..         ...            ...               ...        ...
# 500      6.485           15.4         22.353976   6.953976
# 501      5.854           10.8         22.353976  11.553976
# 503      6.341           14.9         22.353976   7.453976
# 504      6.251           12.6         22.353976   9.753976
# 505      6.185           14.1         22.353976   8.253976
#
# [415 rows x 4 columns]

# %%
sum(model_3_obs['Error']**2)
# Out:
# 27010.95093975901

# %%
x = df_clean['Avg_rooms ']
y = df_clean['MValue']

xy=x*y
n=len(df_clean)

xmean=df_clean['Avg_rooms '].mean()
ymean=df_clean['MValue'].mean()

numerator=xy.sum()-n*xmean*ymean
denominator=(x**2).sum()-n*(xmean**2)

m=numerator/denominator
c=ymean - (m*xmean)
print('intercept-c:',c,'coefficient-m:',m)
# Out:
# intercept-c: -38.406206472126044 coefficient-m: 9.694400761978333

# %%
min_best_model = c+m*df_clean['Avg_rooms ']
df_clean['min_best_model']=min_best_model
df_clean[['Avg_rooms ','MValue','min_best_model']]
# Out:
# <ipython-input-112-023e4fd2b876>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      Avg_rooms   MValue  min_best_model
# 0         7.416    33.2       33.487470
# 1         6.727    27.5       26.808027
# 2         6.781    26.5       27.331525
# 4         6.137    19.3       21.088331
# 5         6.167    20.1       21.379163
# ..          ...     ...             ...
# 500       6.485    15.4       24.461982
# 501       5.854    10.8       18.344816
# 503       6.341    14.9       23.065989
# 504       6.251    12.6       22.193493
# 505       6.185    14.1       21.553662
#
# [415 rows x 3 columns]

# %%
fig,ax=plt.subplots()

ax.scatter(x='Avg_rooms ',y='MValue',data=data)

ax.plot(df_clean['Avg_rooms '],df_clean['min_best_model'],color='red')

ax.set_ylabel('Minutes')
ax.set_xlabel('Units')
ax.set_title('Best Fit Model')
# Out:
# Text(0.5, 1.0, 'Best Fit Model')

# %%
best_fit=pd.DataFrame({'Avg Rooms':df_clean['Avg_rooms '],
                         'M value':df_clean['MValue'],
                         'Predicted M Value':df_clean['min_best_model'],
                         'Error':(df_clean['min_best_model'] - df_clean['MValue'])
                         })
best_fit
# Out:
#      Avg Rooms  M value  Predicted M Value     Error
# 0        7.416     33.2          33.487470  0.287470
# 1        6.727     27.5          26.808027 -0.691973
# 2        6.781     26.5          27.331525  0.831525
# 4        6.137     19.3          21.088331  1.788331
# 5        6.167     20.1          21.379163  1.279163
# ..         ...      ...                ...       ...
# 500      6.485     15.4          24.461982  9.061982
# 501      5.854     10.8          18.344816  7.544816
# 503      6.341     14.9          23.065989  8.165989
# 504      6.251     12.6          22.193493  9.593493
# 505      6.185     14.1          21.553662  7.453662
#
# [415 rows x 4 columns]

# %%
sum(best_fit['Error']**2)
# Out:
# 12457.020598061992

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.30,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import accuracy_score
ypred = model.predict(xtest)

# %%
print("Intercept:",model.intercept_)
print("Coefficients",model.coef_)
# Out:
# Intercept: [-38.40620647]
# Coefficients [[9.69440076]]

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
MSE=mean_squared_error(ypred,ytest)
print("The mean sqaured error of the model is:",MSE)

RS=r2_score(ytest,ypred)
print("The R Square value of the model is:",RS)
# Out:
# The mean sqaured error of the model is: 31.582426996191206
# The R Square value of the model is: 0.557542669343007
